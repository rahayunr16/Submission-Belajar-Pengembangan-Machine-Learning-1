# %% [markdown]
# <a href="https://colab.research.google.com/github/rahayunr16/Submission-Belajar-Pengembangan-Machine-Learning-1/blob/main/File_Kode_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Scrapping Data**
#
# Akan dilakukan scrapping data dari aplikasi Tokopedia di PlayStore
#
# `url='https://play.google.com/store/apps/details?id=com.tokopedia.tkpd&pcampaignid=web_share'`
#
# Data yang digunakan sebesar 11.000 sampel

# %% [markdown]
# **Install Library**

# %%
# !pip install google-play-scraper

import pandas as pd
import datetime
import time
import csv

from types import resolve_bases
from google_play_scraper import app, reviews, Sort
from google.colab import files
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %% [markdown]
# google_play_scaper digunakan untuk mengambil informasi aplikasi dri ulasan Google Play Store
#
# panda untuk format dataframe
#
# datetime agar dapat menentukan rentang waktu

# %% [markdown]
# **Scrapping**

# %%
app_id = 'com.tokopedia.tkpd'

def get_reviews(app_id, lang='id', count=15000, sort=Sort.NEWEST, filter_score_with=None, filter_device_with=None, continuation_token=None):
    try:
        result, continuation_token = reviews(
            app_id,
            lang=lang,
            country='id',
            sort=sort,
            count=count,
            filter_score_with=filter_score_with,
            filter_device_with=filter_device_with,
            continuation_token=continuation_token
        )
        return result, continuation_token
    except Exception as e:
        print("Error:", e)
        return None, None

reviews, continuation_token = get_reviews(app_id)

if reviews is not None:
    print("Jumlah ulasan:", len(reviews))
    if len(reviews) > 0:
        print("Ulasan pertama:")
        print(reviews[0])
else:
    print("Tidak dapat mengambil ulasan.")

time.sleep(1)
# Out:
# Jumlah ulasan: 15000
# Ulasan pertama:
# {'reviewId': '2afd23b3-2d79-4cab-8a71-7c6b81ffa9bf', 'userName': 'Pengguna Google', 'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g', 'content': 'mantap', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '3.306.0', 'at': datetime.datetime(2025, 5, 4, 2, 58, 19), 'replyContent': None, 'repliedAt': None, 'appVersion': '3.306.0'}

# %% [markdown]
# **Tinjau Dataset**

# %%
df = pd.DataFrame(reviews)
df
# Out:
#                                    reviewId         userName  \
# 0      2afd23b3-2d79-4cab-8a71-7c6b81ffa9bf  Pengguna Google
# 1      5d5b845c-1408-41e1-b172-2857b55c457c  Pengguna Google
# 2      b4c62d54-5fa7-4e96-8cba-371a952a7bc9  Pengguna Google
# 3      546f3d9a-e4d4-4987-a323-c547d8f7e3e4  Pengguna Google
# 4      bd35e418-5eed-45e1-91db-eb273fc9ac0b  Pengguna Google
# ...                                     ...              ...
# 14995  a6921862-8688-48e2-8302-e04a2057e3d4      Mamah Fajar
# 14996  ad4ec101-b784-48a3-a17e-3ee9459e759e    Anjing Anjing
# 14997  5609d48d-e844-4c1a-acde-b76b8e1726ac        Keiko Iko
# 14998  2747296a-02c2-4550-8084-05fdda45ba54       Mindo Fals
# 14999  a1908373-45d3-447a-8746-735e40e3cbc9     Ratna Manika
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 3      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 14995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 14996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 14997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 14998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 14999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0                                                 mantap      5
# 1         akun tiba-tiba ke apus pas daftar lagi ga bisa      2
# 2                                           Jelek banget      4
# 3                                                terbaik      5
# 4                          KEMANA FITUR TUKAR TAMBAH!!!!      2
# ...                                                  ...    ...
# 14995                          Najis banget nih aplikasi      1
# 14996                                              bagus      5
# 14997  penanganan masalah keluhan konsumen berhari2 ....      1
# 14998                                       Bagus sekali      5
# 14999                               suka bgt dgn apk ini      4
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 0                  0              3.306.0 2025-05-04 02:58:19
# 1                  0                 None 2025-05-04 02:36:44
# 2                  0                 None 2025-05-04 02:35:48
# 3                  0              3.309.0 2025-05-04 02:20:26
# 4                  0              3.309.0 2025-05-04 01:43:05
# ...              ...                  ...                 ...
# 14995              0                 None 2025-01-03 07:04:56
# 14996              0              3.294.1 2025-01-03 06:56:03
# 14997              0              3.294.1 2025-01-03 06:51:10
# 14998              0                 None 2025-01-03 06:46:28
# 14999              0                 None 2025-01-03 06:26:51
#
#                                             replyContent           repliedAt  \
# 0                                                   None                 NaT
# 1                                                   None                 NaT
# 2                                                   None                 NaT
# 3                                                   None                 NaT
# 4      Hi Toppers, terima kasih untuk rating dan ulas... 2025-03-05 00:27:06
# ...                                                  ...                 ...
# 14995  Halo Toppers, terima kasih atas rating yang ka... 2025-01-03 07:08:01
# 14996  Toppers, terima kasih atas rating yang kamu be... 2025-01-03 07:08:03
# 14997  Hi Toppers, silakan sampaikan kritik/saran ata... 2025-01-03 07:08:04
# 14998  Toppers, terima kasih atas rating yang kamu be... 2025-01-03 06:48:35
# 14999  Hi Toppers, terima kasih untuk rating dan ulas... 2025-01-03 06:40:06
#
#       appVersion
# 0        3.306.0
# 1           None
# 2           None
# 3        3.309.0
# 4        3.309.0
# ...          ...
# 14995       None
# 14996    3.294.1
# 14997    3.294.1
# 14998       None
# 14999       None
#
# [15000 rows x 11 columns]

# %% [markdown]
# **Ubah Nama Kolom**

# %%
def export_to_csv(reviews, file_name:'Tokopedia_Reviews_Scraping.csv'):
    if reviews:
        fieldnames = ["Review ID", "Username", "Review", "Rating", "Date"]

        with open(file_name, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=fieldnames)
            writer.writeheader()

            for review in reviews:
                writer.writerow({
                    "Review ID": review["reviewId"],
                    "Username": review["userName"],
                    "Review": review["content"],
                    "Rating": review["score"],
                    "Date": review["at"],
                })
            print(f"Exported {len(reviews)} reviews to {file_name}")
    else:
        print("No reviews to export.")

export_to_csv(reviews, 'Tokopedia_Reviews_Scraping.csv')
# Out:
# Exported 15000 reviews to Tokopedia_Reviews_Scraping.csv

# %%
data=pd.read_csv('Tokopedia_Reviews_Scraping.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Review ID  15000 non-null  object
#  1   Username   15000 non-null  object
#  2   Review     14999 non-null  object
#  3   Rating     15000 non-null  int64
#  4   Date       15000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 586.1+ KB

# %% [markdown]
# **Unduh Dataset**

# %%
df.to_csv('Tokopedia_Reviews_Scraping.csv', index=False)
files.download('Tokopedia_Reviews_Scraping.csv')
